# %% [markdown]
# <a href="https://colab.research.google.com/github/Kienknu/Kienknu/blob/main/SOA_SMILES_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dataset
# Out:
#      Index                             reactant_smiles reagent_1 Condition  \
# 0        1                                CC1=CC=CC=C1      [OH]       NaN
# 1        2                                CC1=CC=CC=C1      [OH]       NaN
# 2        3                                CC1=CC=CC=C1      [OH]       NaN
# 3        4                            CC1=C[C]C(O)C=C1       O=O      Temp
# 4        5                            CC1=C[C]C(O)C=C1     [N]=O       NaN
# 5        6                            CC1=C[C]C(O)C=C1     [NO2]       NaN
# 6        7                              CC1=CC=C[C]C1O       O=O      Temp
# 7        8                              CC1=CC=C[C]C1O     [N]=O       NaN
# 8        9                              CC1=CC=C[C]C1O     [NO2]       NaN
# 9       10                            CC1=CC(O)[C]C=C1       O=O      Temp
# 10      11                            CC1=CC(O)[C]C=C1     [N]=O       NaN
# ...
